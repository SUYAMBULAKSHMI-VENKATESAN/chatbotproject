# %% [markdown]
# <a href="https://colab.research.google.com/github/SUYAMBULAKSHMI-VENKATESAN/chatbotproject/blob/main/stopwords-removed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#from os import read
import re #regular expression to extract data
import nltk
import pandas as pd
import numpy as np

import spacy #spacy have some simple algorithm to do tokenization of the given dataset
from spacy.lang.en.stop_words import STOP_WORDS #english stopwords are extracted
len(STOP_WORDS) #To know about how many stopwords are available
nlp = spacy.load("en_core_web_sm") #using english language as the preferred language


df = pd.read_csv("dialogs.txt",sep='\t',header=None)
df #converted into table form

# Import stopwords with scikit-learn
#from sklearn.feature_extraction import text
#stop = text.ENGLISH_STOP_WORDS
#print(stop)
#import sklearn
#df = df.head()
#df.shape
# Out:
#                                                       0  \
# 0                                hi, how are you doing?
# 1                         i'm fine. how about yourself?
# 2                   i'm pretty good. thanks for asking.
# 3                     no problem. so how have you been?
# 4                      i've been great. what about you?
# ...                                                 ...
# 3720    that's a good question. maybe it's not old age.
# 3721                              are you right-handed?
# 3722                                  yes. all my life.
# 3723  you're wearing out your right hand. stop using...
# 3724        but i do all my writing with my right hand.
#
#                                                       1
# 0                         i'm fine. how about yourself?
# 1                   i'm pretty good. thanks for asking.
# 2                     no problem. so how have you been?
# 3                      i've been great. what about you?
# ...

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
column_names = ['Column_1','Column_2'] #column headings are given here
df.columns = column_names

# %%
df = df[ df['Column_1'].str.len()!=0] #finding the null data
df.head(3725)
df.shape
# Out:
# (3725, 5)

# %%
df = df[ df['Column_2'].str.len()!=0] #finding the null data
df.head(3725)
df.shape
# Out:
# (3725, 5)

# %%
doc = nlp("what the hell are you doing man , and what the hell is wrong with you . who are you man to tell this to me?")

for token in doc:
  if token.is_stop:
    print(token)
# Out:
# what
# the
# are
# you
# doing
# and
# what
# the
# is
# with
# you
# who
# are
# you
# to
# this
# to
# me

# %%
def removing_stopwords(text):
  doc = nlp(text) #doc variable is used to store the given data
  no_stop_words =[token.text for token in doc if not token.is_stop and not token.is_punct]
  return no_stop_words

# %%
df.columns
# Out:
# Index(['Column_1', 'Column_2', 'Column_2_new', 'Column_1_new'], dtype='object')

# %%
df["Column_2_new"] = df["Column_2"].apply(removing_stopwords)
df["Column_1_new"] = df["Column_1"].apply(removing_stopwords)
#df.head()
value = display(df.head(3725))
# Out:
#                                                Column_1  \
# 0                                hi, how are you doing?
# 1                         i'm fine. how about yourself?
# 2                   i'm pretty good. thanks for asking.
# 3                     no problem. so how have you been?
# 4                      i've been great. what about you?
# ...                                                 ...
# 3720    that's a good question. maybe it's not old age.
# 3721                              are you right-handed?
# 3722                                  yes. all my life.
# 3723  you're wearing out your right hand. stop using...
# 3724        but i do all my writing with my right hand.
#
#                                                Column_2  \
# 0                         i'm fine. how about yourself?
# 1                   i'm pretty good. thanks for asking.
# 2                     no problem. so how have you been?
# 3                      i've been great. what about you?
# ...

# %%
a = df["Column_1_new"]
print(a)

#column = df.head()
#print(data)
#display(data)
# Out:
# 0                                    [hi]
# 1                                  [fine]
# 2          [pretty, good, thanks, asking]
# 3                               [problem]
# 4                                 [great]
#                       ...
# 3720    [good, question, maybe, old, age]
# 3721                      [right, handed]
# 3722                          [yes, life]
# 3723         [wearing, right, hand, stop]
# 3724               [writing, right, hand]
# Name: Column_1_new, Length: 3725, dtype: object

# %%
df["unstemmed"] = df["Column_1_new"]


b = df["unstemmed"]
print(b)
# Out:
# 0                                    [hi]
# 1                                  [fine]
# 2          [pretty, good, thanks, asking]
# 3                               [problem]
# 4                                 [great]
#                       ...
# 3720    [good, question, maybe, old, age]
# 3721                      [right, handed]
# 3722                          [yes, life]
# 3723         [wearing, right, hand, stop]
# 3724               [writing, right, hand]
# Name: unstemmed, Length: 3725, dtype: object

# %%
nlp = spacy.load("en_core_web_sm")
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer



ps = PorterStemmer()
#sentence = "Programmers program with programming languages"
words = word_tokenize(str(b))

for word in words:
  print(word, "|", ps.stem(word))
# Out:
# 0 | 0
# [ | [
# hi | hi
# ] | ]
# 1 | 1
# [ | [
# fine | fine
# ] | ]
# 2 | 2
# [ | [
# pretty | pretti
# , | ,
# good | good
# , | ,
# thanks | thank
# , | ,
# asking | ask
# ] | ]
# 3 | 3
# [ | [
# problem | problem
# ] | ]
# 4 | 4
# [ | [
# great | great
# ] | ]
# ... | ...
# 3720 | 3720
# [ | [
# good | good
# , | ,
# question | question
# , | ,
# maybe | mayb
# , | ,
# old | old
# , | ,
# age | age
# ] | ]
# 3721 | 3721
# [ | [
# right | right
# , | ,
# handed | hand
# ] | ]
# 3722 | 3722
# [ | [
# yes | ye
# , | ,
# life | life
# ] | ]
# 3723 | 3723
# [ | [
# wearing | wear
# , | ,
# right | right
# , | ,
# hand | hand
# , | ,
# stop | stop
# ] | ]
# 3724 | 3724
# [ | [
# writing | write
# , | ,
# right | right
# , | ,
# hand | hand
# ] | ]
# Name | name
# : | :
# unstemmed | unstem
# , | ,
# Length | length
# : | :
# 3725 | 3725
# , | ,
# dtype | dtype
# : | :
# object | object

# %%
values =
stemmer = [values(3725)]
lemmatizing = [values(3725)]
df['stemmer_words'] = stemmer
df['lemmatizing_word'] = lemmatizing
